# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

import warnings
warnings.filterwarnings("ignore")

# %%
# %matplotlib notebook

# %%
import platform
import matplotlib.font_manager as fm

if platform.system() == 'Darwin': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif platform.system() == 'Windows': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')
    
# 글씨 선명하게 출력하는 설정

from IPython.display import set_matplotlib_formats

set_matplotlib_formats("retina")

# %%
import sys
print(sys.stdin.encoding)
print(sys.stdout.encoding)
# Out:
# utf-8
# UTF-8

# %%
df_2005 =pd.read_csv("./data/공공자전거 이용정보(시간대별)_19.12_20.056.csv" ,encoding='cp949')
df_2005
# Out:
#                대여일자  대여시간  대여소번호                         대여소명 대여구분코드   성별  \
# 0        2019-12-01     0    504               504. 신자초교입구교차로    정기권  NaN
# 1        2019-12-01     0   1029                 1029. 롯데 시네마    정기권  NaN
# 2        2019-12-01     0   1153      1153. 발산역 1번, 9번 인근 대여소    정기권  NaN
# 3        2019-12-01     0    512             512. 뚝섬역 1번 출구 옆    정기권  NaN
# 4        2019-12-01     0   1528              1528. 삼각산동 주민센터    정기권  NaN
# ...             ...   ...    ...                          ...    ...  ...
# 6894861  2020-05-31    23   1610            1610. 화랑대역 2번출구 앞    일일권    M
# 6894862  2020-05-31    23   2318    2318. 삼성중앙역4번출구(문화센터더 리빌)    일일권    M
# 6894863  2020-05-31    23   2329  2329. 르네상스호텔사거리 역삼지하보도 2번출구    일일권    M
# 6894864  2020-05-31    23   1450              1450. 화랑대역 7번출구    일일권    M
# 6894865  2020-05-31    23   2418             2418.봉은사역 7번 출구     단체권    M
#
#         연령대코드  이용건수     운동량   탄소량    이동거리  사용시간
# 0        ~10대     3   74.84  0.67  2880.0    17
# 1        ~10대     1  246.71  2.06  8900.0    45
# 2        ~10대     1   25.60  0.23  1010.0    12
# 3        ~10대     1   78.59  0.73  3150.0    17
# 4        ~10대     1   26.15  0.22   930.0     5
# ...       ...   ...     ...   ...     ...   ...
# 6894861   30대     1  231.20  1.65  7120.0    34
# 6894862   30대     1  175.53  1.37  5910.0    40
# 6894863   30대     1    0.00  0.00     0.0    20
# 6894864   40대     1    0.00  0.00     0.0     5
# 6894865   20대     1    0.00  0.00     0.0    12
#
# [6894866 rows x 12 columns]

# %%
import glob
all_data = glob.glob('./data/공공자전거 이용정보(시간대별)_*')
all_data
# Out:
# ['./data/공공자전거 이용정보(시간대별)_21.01.csv',
#  './data/공공자전거 이용정보(시간대별)_19.12_20.056.csv',
#  './data/공공자전거 이용정보(시간대별)_20.09.csv',
#  './data/공공자전거 이용정보(시간대별)_20.08.csv',
#  './data/공공자전거 이용정보(시간대별)_20.11.csv',
#  './data/공공자전거 이용정보(시간대별)_20.10.csv',
#  './data/공공자전거 이용정보(시간대별)_20.12.csv',
#  './data/공공자전거 이용정보(시간대별)_20.06.csv',
#  './data/공공자전거 이용정보(시간대별)_20.07.csv']

# %%
df2101 = pd.read_csv(all_data[0], index_col=False, encoding='cp949', parse_dates=[0])
df2005 = pd.read_csv(all_data[1], index_col=False, encoding='cp949', parse_dates=[0])
df2009 = pd.read_csv(all_data[2], index_col=False, encoding='cp949', parse_dates=[0])
df2008 = pd.read_csv(all_data[3], index_col=False, encoding='cp949', parse_dates=[0])
df2011 = pd.read_csv(all_data[4], index_col=False, encoding='cp949', parse_dates=[0])
df2010 = pd.read_csv(all_data[5], index_col=False, encoding='cp949', parse_dates=[0])
df2012 = pd.read_csv(all_data[6], index_col=False, encoding='cp949', parse_dates=[0])
df2006 = pd.read_csv(all_data[7], index_col=False, encoding='cp949', parse_dates=[0])
df2007 = pd.read_csv(all_data[8], index_col=False, encoding='cp949', parse_dates=[0])

# %%
df = pd.concat([df2005,df2006,df2007,df2008,df2009,df2010,df2011,df2012,df2101])
df.shape
# Out:
# (20521848, 12)

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#                대여일자  대여시간  대여소번호                     대여소명 대여구분코드   성별 연령대코드  \
# 0        2019-12-01     0    504           504. 신자초교입구교차로    정기권  NaN  ~10대
# 1        2019-12-01     0   1029             1029. 롯데 시네마    정기권  NaN  ~10대
# 2        2019-12-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  NaN  ~10대
# 3        2019-12-01     0    512         512. 뚝섬역 1번 출구 옆    정기권  NaN  ~10대
# 4        2019-12-01     0   1528          1528. 삼각산동 주민센터    정기권  NaN  ~10대
# ...             ...   ...    ...                      ...    ...  ...   ...
# 20521843 2021-01-31    23    207        207. 여의나루역 1번출구 앞    단체권  NaN  ~10대
# 20521844 2021-01-31    23   3549             3549.건영아파트 앞    단체권  NaN   20대
# 20521845 2021-01-31    23    248             248. 초원아파트 앞    단체권  NaN   20대
# 20521846 2021-01-31    23    131                131. 증산2교    단체권  NaN   20대
# 20521847 2021-01-31    23    247         247. 당산역 10번출구 앞    단체권    M   40대
#
#           이용건수     운동량   탄소량      이동거리  사용시간
# 0            3   74.84  0.67   2880.00    17
# 1            1  246.71  2.06   8900.00    45
# 2            1   25.60  0.23   1010.00    12
# 3            1   78.59  0.73   3150.00    17
# 4            1   26.15  0.22    930.00     5
# ...        ...     ...   ...       ...   ...
# 20521843     5  916.66  8.66  37335.95   219
# 20521844     2  492.87  4.51  19447.10   133
# 20521845     2  348.43  2.91  12569.64    90
# 20521846     2   98.10  0.77   3302.87    20
# 20521847     1  223.71  2.02   8691.10    52
#
# [20521848 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20521848 entries, 0 to 20521847
# Data columns (total 12 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   대여일자    datetime64[ns]
#  1   대여시간    int64
#  2   대여소번호   int64
#  3   대여소명    object
#  4   대여구분코드  object
#  5   성별      object
#  6   연령대코드   object
#  7   이용건수    int64
#  8   운동량     object
#  9   탄소량     object
#  10  이동거리    float64
#  11  사용시간    int64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(6)
# memory usage: 1.8+ GB

# %%
df.isnull().sum()
# Out:
# 대여일자             0
# 대여시간             0
# 대여소번호            0
# 대여소명             0
# 대여구분코드           0
# 성별        10229315
# 연령대코드            0
# 이용건수             0
# 운동량              0
# 탄소량              0
# 이동거리             0
# 사용시간             0
# dtype: int64

# %%
df = df.drop('성별',axis=1)
df
# Out:
#                대여일자  대여시간  대여소번호                     대여소명 대여구분코드 연령대코드  이용건수  \
# 0        2019-12-01     0    504           504. 신자초교입구교차로    정기권  ~10대     3
# 1        2019-12-01     0   1029             1029. 롯데 시네마    정기권  ~10대     1
# 2        2019-12-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  ~10대     1
# 3        2019-12-01     0    512         512. 뚝섬역 1번 출구 옆    정기권  ~10대     1
# 4        2019-12-01     0   1528          1528. 삼각산동 주민센터    정기권  ~10대     1
# ...             ...   ...    ...                      ...    ...   ...   ...
# 20521843 2021-01-31    23    207        207. 여의나루역 1번출구 앞    단체권  ~10대     5
# 20521844 2021-01-31    23   3549             3549.건영아파트 앞    단체권   20대     2
# 20521845 2021-01-31    23    248             248. 초원아파트 앞    단체권   20대     2
# 20521846 2021-01-31    23    131                131. 증산2교    단체권   20대     2
# 20521847 2021-01-31    23    247         247. 당산역 10번출구 앞    단체권   40대     1
#
#              운동량   탄소량      이동거리  사용시간
# 0          74.84  0.67   2880.00    17
# 1         246.71  2.06   8900.00    45
# 2          25.60  0.23   1010.00    12
# 3          78.59  0.73   3150.00    17
# 4          26.15  0.22    930.00     5
# ...          ...   ...       ...   ...
# 20521843  916.66  8.66  37335.95   219
# 20521844  492.87  4.51  19447.10   133
# 20521845  348.43  2.91  12569.64    90
# 20521846   98.10  0.77   3302.87    20
# 20521847  223.71  2.02   8691.10    52
#
# [20521848 rows x 11 columns]

# %%
df.insert(1,'년',df['대여일자'].dt.year)
df.insert(2,'월',df['대여일자'].dt.month)
df.insert(3,'일',df['대여일자'].dt.day)
df
# Out:
#                대여일자     년   월   일  대여시간  대여소번호                     대여소명  \
# 0        2019-12-01  2019  12   1     0    504           504. 신자초교입구교차로
# 1        2019-12-01  2019  12   1     0   1029             1029. 롯데 시네마
# 2        2019-12-01  2019  12   1     0   1153  1153. 발산역 1번, 9번 인근 대여소
# 3        2019-12-01  2019  12   1     0    512         512. 뚝섬역 1번 출구 옆
# 4        2019-12-01  2019  12   1     0   1528          1528. 삼각산동 주민센터
# ...             ...   ...  ..  ..   ...    ...                      ...
# 20521843 2021-01-31  2021   1  31    23    207        207. 여의나루역 1번출구 앞
# 20521844 2021-01-31  2021   1  31    23   3549             3549.건영아파트 앞
# 20521845 2021-01-31  2021   1  31    23    248             248. 초원아파트 앞
# 20521846 2021-01-31  2021   1  31    23    131                131. 증산2교
# 20521847 2021-01-31  2021   1  31    23    247         247. 당산역 10번출구 앞
#
#          대여구분코드 연령대코드  이용건수     운동량   탄소량      이동거리  사용시간
# 0           정기권  ~10대     3   74.84  0.67   2880.00    17
# 1           정기권  ~10대     1  246.71  2.06   8900.00    45
# 2           정기권  ~10대     1   25.60  0.23   1010.00    12
# 3           정기권  ~10대     1   78.59  0.73   3150.00    17
# 4           정기권  ~10대     1   26.15  0.22    930.00     5
# ...         ...   ...   ...     ...   ...       ...   ...
# 20521843    단체권  ~10대     5  916.66  8.66  37335.95   219
# 20521844    단체권   20대     2  492.87  4.51  19447.10   133
# 20521845    단체권   20대     2  348.43  2.91  12569.64    90
# 20521846    단체권   20대     2   98.10  0.77   3302.87    20
# 20521847    단체권   40대     1  223.71  2.02   8691.10    52
#
# [20521848 rows x 14 columns]

# %%
df.shape
# Out:
# (20521848, 14)

# %%
df['대여소명'].unique()
# Out:
# array(['504. 신자초교입구교차로', '1029. 롯데 시네마', '1153. 발산역 1번, 9번 인근 대여소', ...,
#        '3863. 동일로58길 입구', '4607. 국립중앙박물관 -용산가족공원 앞',
#        '3878. 장로회신학대학교 주기철 기념관'], dtype=object)

# %%
df_hanriver = df[df['대여소명'].str.contains
('하늘공원|선유도역|마포구민체육센터|망원2빗물펌프장|여의나루역|여의도역|국회의사당역|노들역|노들섬|한강트럼프월드|아크로리버뷰|신반포역|고속터미널역|뚝섬유원지역|몽촌토성역|천호역|암사동선사유적지')]
df_hanriver['대여소명'].unique()
# Out:
# array(['2219. 고속터미널역 8-1번, 8-2번 출구 사이', '1268. 몽촌토성역 1번출구 옆',
#        '1009. 천호역4번출구(현대백화점)', '204. 국회의사당역 5번출구 옆', '207. 여의나루역 1번출구 앞',
#        '2213. 고속터미널역 5번출구 앞', '212. 여의도역 1번출구 옆', '182. 망원2빗물펌프장 앞',
#        '502. 뚝섬유원지역 1번출구 앞', '2002. 노들역 1번출구', '2217.아크로리버뷰 부지 앞',
#        '228. 선유도역 3번출구 앞', '211. 여의도역 4번출구 옆', '1264. 천호역 10번 출구 앞',
#        '152. 마포구민체육센터 앞', '2214. 신반포역 2번출구 앞', '203. 국회의사당역 3번출구 옆',
#        '440. 하늘공원 입구', '870.노들섬 서측 앞', '869.노들섬 동측 앞', '2077.노들역 3번출구',
#        '2535.신반포역 3번출구 뒤', '4605. 노들섬 다목적홀(동쪽) 숲, 앞', '4619. 한강트럼프월드3차 앞'],
#       dtype=object)

# %%
df_hanriver.reset_index(drop=True,inplace=True)
df_hanriver
# Out:
#              대여일자     년   월   일  대여시간  대여소번호                           대여소명  \
# 0      2019-12-01  2019  12   1     0   2219  2219. 고속터미널역 8-1번, 8-2번 출구 사이
# 1      2019-12-01  2019  12   1     0   1268             1268. 몽촌토성역 1번출구 옆
# 2      2019-12-01  2019  12   1     0   1009           1009. 천호역4번출구(현대백화점)
# 3      2019-12-01  2019  12   1     0    204             204. 국회의사당역 5번출구 옆
# 4      2019-12-01  2019  12   1     0    207              207. 여의나루역 1번출구 앞
# ...           ...   ...  ..  ..   ...    ...                            ...
# 505227 2021-01-31  2021   1  31    23    207              207. 여의나루역 1번출구 앞
# 505228 2021-01-31  2021   1  31    23    152                152. 마포구민체육센터 앞
# 505229 2021-01-31  2021   1  31    23   4619              4619. 한강트럼프월드3차 앞
# 505230 2021-01-31  2021   1  31    23    207              207. 여의나루역 1번출구 앞
# 505231 2021-01-31  2021   1  31    23    207              207. 여의나루역 1번출구 앞
#
#        대여구분코드 연령대코드  이용건수     운동량   탄소량      이동거리  사용시간
# 0         정기권  ~10대     1  200.34  1.73   7440.00    47
# 1         정기권   20대     1   39.47  0.41   1780.00    16
# 2         정기권   20대     2  347.37  2.39  10320.00    61
# 3         정기권   20대     1  110.42  1.00   4290.00    19
# 4         정기권   20대     1    0.00  0.00      0.00     0
# ...       ...   ...   ...     ...   ...       ...   ...
# 505227    일일권  ~10대     1    0.00  0.00      0.00    43
# 505228    일일권   20대     1  114.94  1.50   6450.00    43
# 505229    일일권   20대     2  282.84  4.11  17707.58   138
# 505230    일일권   30대     1  250.30  1.61   6945.89    38
# 505231    단체권  ~10대     5  916.66  8.66  37335.95   219
#
# [505232 rows x 14 columns]

# %%
df_hanriver['대여소명'] = df_hanriver['대여소명'].str.split('.').str[1]
df_hanriver
# Out:
#              대여일자     년   월   일  대여시간  대여소번호                      대여소명 대여구분코드  \
# 0      2019-12-01  2019  12   1     0   2219   고속터미널역 8-1번, 8-2번 출구 사이    정기권
# 1      2019-12-01  2019  12   1     0   1268              몽촌토성역 1번출구 옆    정기권
# 2      2019-12-01  2019  12   1     0   1009            천호역4번출구(현대백화점)    정기권
# 3      2019-12-01  2019  12   1     0    204             국회의사당역 5번출구 옆    정기권
# 4      2019-12-01  2019  12   1     0    207              여의나루역 1번출구 앞    정기권
# ...           ...   ...  ..  ..   ...    ...                       ...    ...
# 505227 2021-01-31  2021   1  31    23    207              여의나루역 1번출구 앞    일일권
# 505228 2021-01-31  2021   1  31    23    152                마포구민체육센터 앞    일일권
# 505229 2021-01-31  2021   1  31    23   4619               한강트럼프월드3차 앞    일일권
# 505230 2021-01-31  2021   1  31    23    207              여의나루역 1번출구 앞    일일권
# 505231 2021-01-31  2021   1  31    23    207              여의나루역 1번출구 앞    단체권
#
#        연령대코드  이용건수     운동량   탄소량      이동거리  사용시간
# 0       ~10대     1  200.34  1.73   7440.00    47
# 1        20대     1   39.47  0.41   1780.00    16
# 2        20대     2  347.37  2.39  10320.00    61
# 3        20대     1  110.42  1.00   4290.00    19
# 4        20대     1    0.00  0.00      0.00     0
# ...      ...   ...     ...   ...       ...   ...
# 505227  ~10대     1    0.00  0.00      0.00    43
# 505228   20대     1  114.94  1.50   6450.00    43
# 505229   20대     2  282.84  4.11  17707.58   138
# 505230   30대     1  250.30  1.61   6945.89    38
# 505231  ~10대     5  916.66  8.66  37335.95   219
#
# [505232 rows x 14 columns]

# %%
df_hanriver.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505232 entries, 0 to 505231
# Data columns (total 14 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   대여일자    505232 non-null  datetime64[ns]
#  1   년       505232 non-null  int64
#  2   월       505232 non-null  int64
#  3   일       505232 non-null  int64
#  4   대여시간    505232 non-null  int64
#  5   대여소번호   505232 non-null  int64
#  6   대여소명    505232 non-null  object
#  7   대여구분코드  505232 non-null  object
#  8   연령대코드   505232 non-null  object
#  9   이용건수    505232 non-null  int64
#  10  운동량     505232 non-null  object
#  11  탄소량     505232 non-null  object
#  12  이동거리    505232 non-null  float64
#  13  사용시간    505232 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(7), object(5)
# memory usage: 54.0+ MB

# %%
df_hanriver.to_csv('df_hanriver.csv', index=False)

# %%
df_hanriver =pd.read_csv("./df_hanriver.csv" ,parse_dates=[0])
df_hanriver
# Out:
#              대여일자     년   월   일  대여시간  대여소번호                      대여소명 대여구분코드  \
# 0      2019-12-01  2019  12   1     0   2219   고속터미널역 8-1번, 8-2번 출구 사이    정기권
# 1      2019-12-01  2019  12   1     0   1268              몽촌토성역 1번출구 옆    정기권
# 2      2019-12-01  2019  12   1     0   1009            천호역4번출구(현대백화점)    정기권
# 3      2019-12-01  2019  12   1     0    204             국회의사당역 5번출구 옆    정기권
# 4      2019-12-01  2019  12   1     0    207              여의나루역 1번출구 앞    정기권
# ...           ...   ...  ..  ..   ...    ...                       ...    ...
# 505227 2021-01-31  2021   1  31    23    207              여의나루역 1번출구 앞    일일권
# 505228 2021-01-31  2021   1  31    23    152                마포구민체육센터 앞    일일권
# 505229 2021-01-31  2021   1  31    23   4619               한강트럼프월드3차 앞    일일권
# 505230 2021-01-31  2021   1  31    23    207              여의나루역 1번출구 앞    일일권
# 505231 2021-01-31  2021   1  31    23    207              여의나루역 1번출구 앞    단체권
#
#        연령대코드  이용건수     운동량   탄소량      이동거리  사용시간
# 0       ~10대     1  200.34  1.73   7440.00    47
# 1        20대     1   39.47  0.41   1780.00    16
# 2        20대     2  347.37  2.39  10320.00    61
# 3        20대     1  110.42  1.00   4290.00    19
# 4        20대     1    0.00  0.00      0.00     0
# ...      ...   ...     ...   ...       ...   ...
# 505227  ~10대     1    0.00  0.00      0.00    43
# 505228   20대     1  114.94  1.50   6450.00    43
# 505229   20대     2  282.84  4.11  17707.58   138
# 505230   30대     1  250.30  1.61   6945.89    38
# 505231  ~10대     5  916.66  8.66  37335.95   219
#
# [505232 rows x 14 columns]

# %%
df_place_month = df_hanriver.groupby(['대여소명','월'],as_index=False).sum().sort_values(by='이용건수',ascending=False)
df_place_month.reset_index(drop=True,inplace=True)
df_place_month
# Out:
#                    대여소명   월         년       일   대여시간    대여소번호   이용건수  \
# 0         뚝섬유원지역 1번출구 앞   5  12602780   99927  92377  3131978  21789
# 1          여의나루역 1번출구 앞   5  11471580   90413  83037  1175553  19164
# 2         뚝섬유원지역 1번출구 앞   9  13081520  107526  94844  3250952  17410
# 3         뚝섬유원지역 1번출구 앞   4  11467540   86996  84233  2849854  16406
# 4         뚝섬유원지역 1번출구 앞   6  11954360   88211  86406  2970836  16001
# ..                  ...  ..       ...     ...    ...      ...    ...
# 250            노들섬 동측 앞   4    248460    2519   1915   106887    133
# 251         한강트럼프월드3차 앞   1    214226    2660   1766   489614    118
# 252            노들섬 동측 앞   1    210184    2020   1663    90376    112
# 253         신반포역 3번출구 뒤   1    169764    1514   1273   212940     89
# 254   노들섬 다목적홀(동쪽) 숲, 앞  12     38380     557    326    87495     23
#
#              이동거리     사용시간
# 0    1.021227e+08  1130689
# 1    1.077752e+08  1114688
# 2    1.870871e+07   846642
# 3    9.316625e+07   871511
# 4    1.522342e+08   754973
# ..            ...      ...
# 250  0.000000e+00     6481
# 251  6.164496e+05     4622
# 252  4.994677e+05     4837
# 253  4.870603e+05     4223
# 254  3.499043e+04      946
#
# [255 rows x 9 columns]

# %%
sns.barplot(x='월',y='이용건수',data=df_place_month)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='월', ylabel='이용건수'>

# %%
# 대여시간별 이용건수 합계
time_counts = df_hanriver.groupby('대여시간',as_index=False).sum().sort_values(by='이용건수',ascending=False)
time_counts.reset_index(drop=True, inplace=True)
time_counts
# Out:
#     대여시간         년       월       일     대여소번호   이용건수          이동거리     사용시간
# 0     18  89120415  297119  702992  39784687  85009  3.971957e+08  3662734
# 1     17  87874161  293144  700192  37566197  82516  3.479044e+08  3831910
# 2     19  73851158  247142  578213  34059326  70067  2.809135e+08  3268998
# 3     16  73968645  245004  589201  32812120  65624  3.179185e+08  3419278
# 4     20  66914507  227181  526103  31076986  65060  2.749513e+08  3073614
# 5     21  62708880  214265  492018  28294965  61218  3.309898e+08  2714455
# 6     15  64812072  213251  514295  29136554  54481  2.469591e+08  3002229
# 7     22  51178582  174016  405273  22626989  48718  1.936518e+08  1990550
# 8     14  56536068  186075  448867  25116420  44108  2.049876e+08  2405105
# 9     13  49833511  166161  392994  21647341  35268  1.271083e+08  1768006
# 10    23  36598261  123828  288993  15140844  32010  9.913169e+07  1306157
# 11     8  43886304  152381  343753  17311089  30739  6.432475e+07   604017
# 12    12  44355291  150051  351770  18699099  28623  8.666109e+07  1278566
# 13    11  38155795  129774  302463  15538052  23652  8.078687e+07  1041355
# 14     0  27033408   92032  214448  11007043  20741  6.995174e+07   835068
# 15     9  32447241  112066  253822  14161077  19194  4.194738e+07   564819
# 16     7  28217411   96611  222991  12191212  17933  3.409917e+07   406039
# 17    10  28706156   99851  224827  12481521  16859  7.395887e+07   706662
# 18     1  18486844   62930  146175   8018871  12918  7.522817e+07   494380
# 19     2  13305542   44898  105674   5931098   8498  2.279341e+07   304720
# 20     6  12586613   42928   99405   5445273   6770  1.628268e+07   213672
# 21     3   8380857   28630   66448   3644402   5119  1.260245e+07   176891
# 22     4   6068000   20831   47559   2599564   3495  7.181553e+06   117334
# 23     5   5542823   18664   43982   2610204   2999  6.970098e+06   105477

# %%
sns.barplot(x='대여시간',y='이용건수',data=time_counts)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='대여시간', ylabel='이용건수'>

# %%
# 일일사용자 vs 정기사용자
plt.figure(figsize=(4,4))
sns.countplot(data=df_hanriver, x='대여구분코드')
# Out:
# <img src="data:image/png;base64,..." width="400">
# <AxesSubplot:xlabel='대여구분코드', ylabel='count'>

# %%
# 일일사용자 vs 정기사용자
sns.countplot(data=df_hanriver, x='연령대코드')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='연령대코드', ylabel='count'>

# %%
df_hanriver['요일']= df_hanriver['대여일자'].dt.dayofweek
df_hanriver
# Out:
#              대여일자     년   월   일  대여시간  대여소번호                      대여소명 대여구분코드  \
# 0      2019-12-01  2019  12   1     0   2219   고속터미널역 8-1번, 8-2번 출구 사이    정기권
# 1      2019-12-01  2019  12   1     0   1268              몽촌토성역 1번출구 옆    정기권
# 2      2019-12-01  2019  12   1     0   1009            천호역4번출구(현대백화점)    정기권
# 3      2019-12-01  2019  12   1     0    204             국회의사당역 5번출구 옆    정기권
# 4      2019-12-01  2019  12   1     0    207              여의나루역 1번출구 앞    정기권
# ...           ...   ...  ..  ..   ...    ...                       ...    ...
# 505227 2021-01-31  2021   1  31    23    207              여의나루역 1번출구 앞    일일권
# 505228 2021-01-31  2021   1  31    23    152                마포구민체육센터 앞    일일권
# 505229 2021-01-31  2021   1  31    23   4619               한강트럼프월드3차 앞    일일권
# 505230 2021-01-31  2021   1  31    23    207              여의나루역 1번출구 앞    일일권
# 505231 2021-01-31  2021   1  31    23    207              여의나루역 1번출구 앞    단체권
#
#        연령대코드  이용건수     운동량   탄소량      이동거리  사용시간  요일
# 0       ~10대     1  200.34  1.73   7440.00    47   6
# 1        20대     1   39.47  0.41   1780.00    16   6
# 2        20대     2  347.37  2.39  10320.00    61   6
# 3        20대     1  110.42  1.00   4290.00    19   6
# 4        20대     1    0.00  0.00      0.00     0   6
# ...      ...   ...     ...   ...       ...   ...  ..
# 505227  ~10대     1    0.00  0.00      0.00    43   6
# 505228   20대     1  114.94  1.50   6450.00    43   6
# 505229   20대     2  282.84  4.11  17707.58   138   6
# 505230   30대     1  250.30  1.61   6945.89    38   6
# 505231  ~10대     5  916.66  8.66  37335.95   219   6
#
# [505232 rows x 15 columns]

# %%
# 이용건수 대비 사용시간 구하기
df_place_count = df_hanriver.groupby(['대여소명'],as_index=False).sum().sort_values(by='이용건수',ascending=False)
df_place_count.reset_index(drop=True,inplace=True)
df_place_count
# Out:
#                         대여소명          년       월       일    대여시간     대여소번호  \
# 0              뚝섬유원지역 1번출구 앞  114544240  382242  910465  841254  28465910
# 1               여의나루역 1번출구 앞  106933010  353194  845175  768524  10957959
# 2                 마포구민체육센터 앞   95429125  321647  758575  697353   7180784
# 3    고속터미널역 8-1번, 8-2번 출구 사이   78672680  255708  622037  597703  86423393
# 4                   노들역 1번출구   61603852  197350  483163  442863  61054994
# 5             천호역4번출구(현대백화점)   64067892  216690  506118  454458  32002453
# 6                선유도역 3번출구 앞   61911083  211527  491282  450777   6987972
# 7               몽촌토성역 1번출구 옆   54269407  182935  425216  401052  34066088
# 8                아크로리버뷰 부지 앞   45985339  156429  363289  338457  50470005
# 9                여의도역 4번출구 옆   50386559  173600  396087  353339   5263184
# 10                망원2빗물펌프장 앞   44601736  148074  352996  328620   4018560
# 11              천호역 10번 출구 앞   39868511  134989  313221  284005  24947568
# 12               여의도역 1번출구 옆   36537541  123576  287091  248168   3834656
# 13             국회의사당역 3번출구 옆   32887273  113628  257436  228006   3305043
# 14             고속터미널역 5번출구 앞   26611380   89870  209566  186497  29154062
# 15                  노들섬 서측 앞   21168027   83262  169833  171932   9116730
# 16               신반포역 2번출구 앞   21975428   67263  170471  164318  24086106
# 17             국회의사당역 5번출구 옆   23532759   80196  185076  169043   2376600
# 18                   하늘공원 입구   18172036   58872  141864  139769   3958240
# 19                  노들역 3번출구    9837636   42163   79847   68170  10114990
# 20                  노들섬 동측 앞    7266044   29276   57233   57777   3125793
# 21               신반포역 3번출구 뒤    3737084   15851   30110   27350   4689750
# 22         노들섬 다목적홀(동쪽) 숲, 앞     355677     385    3647    2808    810480
# 23               한강트럼프월드3차 앞     214226     106    2660    1766    489614
#
#       이용건수          이동거리     사용시간      요일
# 0   137466  5.903380e+08  6505079  180470
# 1   127847  6.269426e+08  6738493  162552
# 2    87636  3.601636e+08  4204979  153152
# 3    68645  3.490173e+08  3634134  124890
# 4    46488  2.203209e+08  2228300   95771
# 5    44617  1.403422e+08  1313051   97801
# 6    42546  9.706523e+07  1524838   94314
# 7    38547  1.323586e+08  1489050   88224
# 8    33064  1.639238e+08  1760112   74190
# 9    32913  1.005512e+08   980937   69191
# 10   30726  1.355394e+08  1460178   70991
# 11   24946  6.600048e+07   663957   57373
# 12   23167  7.551198e+07   681226   50441
# 13   20952  8.383567e+07   609792   41407
# 14   15798  8.276791e+07   578376   37076
# 15   14349  3.401796e+07   614494   37731
# 16   14218  5.953287e+07   755748   35266
# 17   14205  3.228605e+07   425667   31290
# 18   11618  5.504688e+07   607158   32692
# 19    5490  4.339001e+06   241625   14993
# 20    4071  1.743890e+06   176478   12464
# 21    1996  1.355998e+06    86437    5858
# 22     196  8.820061e+05     7305     667
# 23     118  6.164496e+05     4622     332

# %%
df_place_count['사용시간평균'] = df_place_count['사용시간']/df_place_count['이용건수']
df_place_count
# Out:
#                         대여소명          년       월       일    대여시간     대여소번호  \
# 0              뚝섬유원지역 1번출구 앞  114544240  382242  910465  841254  28465910
# 1               여의나루역 1번출구 앞  106933010  353194  845175  768524  10957959
# 2                 마포구민체육센터 앞   95429125  321647  758575  697353   7180784
# 3    고속터미널역 8-1번, 8-2번 출구 사이   78672680  255708  622037  597703  86423393
# 4                   노들역 1번출구   61603852  197350  483163  442863  61054994
# 5             천호역4번출구(현대백화점)   64067892  216690  506118  454458  32002453
# 6                선유도역 3번출구 앞   61911083  211527  491282  450777   6987972
# 7               몽촌토성역 1번출구 옆   54269407  182935  425216  401052  34066088
# 8                아크로리버뷰 부지 앞   45985339  156429  363289  338457  50470005
# 9                여의도역 4번출구 옆   50386559  173600  396087  353339   5263184
# 10                망원2빗물펌프장 앞   44601736  148074  352996  328620   4018560
# 11              천호역 10번 출구 앞   39868511  134989  313221  284005  24947568
# 12               여의도역 1번출구 옆   36537541  123576  287091  248168   3834656
# 13             국회의사당역 3번출구 옆   32887273  113628  257436  228006   3305043
# 14             고속터미널역 5번출구 앞   26611380   89870  209566  186497  29154062
# 15                  노들섬 서측 앞   21168027   83262  169833  171932   9116730
# 16               신반포역 2번출구 앞   21975428   67263  170471  164318  24086106
# 17             국회의사당역 5번출구 옆   23532759   80196  185076  169043   2376600
# 18                   하늘공원 입구   18172036   58872  141864  139769   3958240
# 19                  노들역 3번출구    9837636   42163   79847   68170  10114990
# 20                  노들섬 동측 앞    7266044   29276   57233   57777   3125793
# 21               신반포역 3번출구 뒤    3737084   15851   30110   27350   4689750
# 22         노들섬 다목적홀(동쪽) 숲, 앞     355677     385    3647    2808    810480
# 23               한강트럼프월드3차 앞     214226     106    2660    1766    489614
#
#       이용건수          이동거리     사용시간      요일     사용시간평균
# 0   137466  5.903380e+08  6505079  180470  47.321367
# 1   127847  6.269426e+08  6738493  162552  52.707478
# 2    87636  3.601636e+08  4204979  153152  47.982325
# 3    68645  3.490173e+08  3634134  124890  52.940986
# 4    46488  2.203209e+08  2228300   95771  47.932800
# 5    44617  1.403422e+08  1313051   97801  29.429388
# 6    42546  9.706523e+07  1524838   94314  35.839750
# 7    38547  1.323586e+08  1489050   88224  38.629465
# 8    33064  1.639238e+08  1760112   74190  53.233487
# 9    32913  1.005512e+08   980937   69191  29.803938
# 10   30726  1.355394e+08  1460178   70991  47.522554
# 11   24946  6.600048e+07   663957   57373  26.615770
# 12   23167  7.551198e+07   681226   50441  29.405016
# 13   20952  8.383567e+07   609792   41407  29.104238
# 14   15798  8.276791e+07   578376   37076  36.610710
# 15   14349  3.401796e+07   614494   37731  42.824866
# 16   14218  5.953287e+07   755748   35266  53.154311
# 17   14205  3.228605e+07   425667   31290  29.965998
# 18   11618  5.504688e+07   607158   32692  52.260114
# 19    5490  4.339001e+06   241625   14993  44.011840
# 20    4071  1.743890e+06   176478   12464  43.350037
# 21    1996  1.355998e+06    86437    5858  43.305110
# 22     196  8.820061e+05     7305     667  37.270408
# 23     118  6.164496e+05     4622     332  39.169492

# %%
df_place_count['사용시간평균'].mean()
# Out:
# 41.26631029265608

# %%
plt.figure(figsize=(13,4))
sns.barplot(x='사용시간평균',y='대여소명',data=df_place_count)
# Out:
# <img src="data:image/png;base64,..." width="1300">
# <AxesSubplot:xlabel='사용시간평균', ylabel='대여소명'>

# %%
plt.figure(figsize=(14,6))
sns.scatterplot(x='이용건수',y='사용시간평균',hue='대여소명',data=df_place_count)
# Out:
# <img src="data:image/png;base64,..." width="1400">
# <AxesSubplot:xlabel='이용건수', ylabel='사용시간평균'>

# %%
df_place_count.corr()
# Out:
#                년         월         일      대여시간     대여소번호      이용건수      이동거리  \
# 년       1.000000  0.999105  0.999963  0.999165  0.413343  0.960464  0.922404
# 월       0.999105  1.000000  0.999244  0.998150  0.396426  0.958590  0.916065
# 일       0.999963  0.999244  1.000000  0.999249  0.410615  0.961497  0.923165
# 대여시간    0.999165  0.998150  0.999249  1.000000  0.427497  0.961379  0.924909
# 대여소번호   0.413343  0.396426  0.410615  0.427497  1.000000  0.318795  0.367653
# 이용건수    0.960464  0.958590  0.961497  0.961379  0.318795  1.000000  0.983337
# 이동거리    0.922404  0.916065  0.923165  0.924909  0.367653  0.983337  1.000000
# 사용시간    0.922215  0.917583  0.923455  0.926366  0.335093  0.986775  0.995135
# 요일      0.996693  0.995587  0.996922  0.998489  0.430657  0.961209  0.925433
# 사용시간평균  0.244023  0.228918  0.245404  0.268339  0.354600  0.337609  0.437310
#
#             사용시간        요일    사용시간평균
# 년       0.922215  0.996693  0.244023
# 월       0.917583  0.995587  0.228918
# 일       0.923455  0.996922  0.245404
# 대여시간    0.926366  0.998489  0.268339
# 대여소번호   0.335093  0.430657  0.354600
# 이용건수    0.986775  0.961209  0.337609
# 이동거리    0.995135  0.925433  0.437310
# 사용시간    1.000000  0.929211  0.461285
# 요일      0.929211  1.000000  0.300228
# 사용시간평균  0.461285  0.300228  1.000000
